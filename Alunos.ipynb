# %% [markdown]
# <a href="https://colab.research.google.com/github/Gus-maker/Pandas/blob/main/Alunos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Desafio aula 1
# 1) Importe o arquivo alunos.csv e armazene seu conteúdo em um DataFrame Pandas.
#
# 2) Visualize as primeiras 7 linhas do DataFrame e as 5 últimas.
#
# 3) Confira a quantidade de linhas e colunas desse DataFrame.
#
# 4) Explore as colunas do DataFrame e analise os tipos dos dados presentes em cada coluna.
#
# Extra: Calcule algumas estatísticas descritivas básicas dos dados do DataFrame (média, desvio padrão, etc). Dica: pesquise pelo método describe.

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
df = pd.read_csv(url)

# %%
#Mostrando as 7 primeiras linhas
df.head(7)
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True
# 5  Bruna     23    NaN     False
# 6   Dara     21    7.0      True

# %%
#Mostrando as 5 últimas linhas
df.tail(5)
# Out:
#       Nome  Idade  Notas  Aprovado
# 13   Mirla     25    9.0      True
# 14   Paulo     37    NaN     False
# 15  Mylena     29    7.0      True
# 16   Lucas     33    NaN     False
# 17   Nadia     34    8.0      True

# %%
#Quantidade de linhas e colunas
df.shape
# Out:
# (18, 4)

# %%
#Explore as colunas do DataFrame e analise os tipos dos dados presentes em cada coluna.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nome      18 non-null     object
#  1   Idade     18 non-null     int64
#  2   Notas     12 non-null     float64
#  3   Aprovado  18 non-null     bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 578.0+ bytes

# %%
print("Coluna Nome:\n")
df['Nome']
# Out:
# Coluna Nome:
# 0           Ary
# 1           Ana
# 2         Cátia
# 3         Denis
# 4          Beto
# 5         Bruna
# 6          Dara
# 7        Carlos
# 8         Alice
# 9         Vitor
# 10       Daniel
# 11         Igor
# 12    Sthefanie
# 13        Mirla
# 14        Paulo
# 15       Mylena
# 16        Lucas
# 17        Nadia
# Name: Nome, dtype: object

# %%
print("\nColuna Idade:\n")
df['Idade']
# Out:
# Coluna Idade:
# 0     20
# 1     18
# 2     27
# 3     18
# 4     21
# 5     23
# 6     21
# 7     19
# 8     35
# 9     28
# 10    21
# 11    24
# 12    26
# 13    25
# 14    37
# 15    29
# 16    33
# 17    34
# Name: Idade, dtype: int64

# %%
print("\nColuna Notas:\n")
df['Notas']
# Out:
# Coluna Notas:
# 0      7.5
# 1      NaN
# 2      2.5
# 3      5.0
# 4     10.0
# 5      NaN
# 6      7.0
# 7      6.0
# 8      5.6
# 9      NaN
# 10     NaN
# 11     4.5
# 12     9.5
# 13     9.0
# 14     NaN
# 15     7.0
# 16     NaN
# 17     8.0
# Name: Notas, dtype: float64

# %%
print("\nColuna Aprovado:\n")
df['Aprovado']
# Out:
# Coluna Aprovado:
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6      True
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13     True
# 14    False
# 15     True
# 16    False
# 17     True
# Name: Aprovado, dtype: bool

# %%
#Extra: Calcule algumas estatísticas descritivas básicas dos dados do DataFrame (média, desvio padrão, etc). Dica: pesquise pelo método describe.
df.describe()
# Out:
#            Idade      Notas
# count  18.000000  12.000000
# mean   25.500000   6.800000
# std     6.070662   2.204953
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# 1) Verifique se a base de dados possui dados nulos e, caso tenha, realize o tratamento desses dados nulos da forma que achar mais coerente com a situação.
#
# 2) Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados.
#
# 3) Aplique um filtro que selecione apenas os alunos que foram aprovados.
#
# 4) Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv".
#
# Extra: Ao conferir as notas dos alunos aprovados, notamos que algumas notas estavam incorretas. As alunas que tiraram nota 7.0, na verdade, tinham um ponto extra que não foi contabilizado. Sendo assim, substitua as notas 7.0 da base de dados por 8.0. Dica: pesquise pelo método replace.

# %%
df.isnull()
# Out:
#      Nome  Idade  Notas  Aprovado
# 0   False  False  False     False
# 1   False  False   True     False
# 2   False  False  False     False
# 3   False  False  False     False
# 4   False  False  False     False
# 5   False  False   True     False
# 6   False  False  False     False
# 7   False  False  False     False
# 8   False  False  False     False
# 9   False  False   True     False
# 10  False  False   True     False
# 11  False  False  False     False
# 12  False  False  False     False
# 13  False  False  False     False
# 14  False  False   True     False
# 15  False  False  False     False
# 16  False  False   True     False
# 17  False  False  False     False

# %%
df.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       6
# Aprovado    0
# dtype: int64

# %%
#Caso tenhamos uma perda nos dados, considerando que os alunos não tiveram suas notas registradas por algum erro no sistema, podemos usar essa função que substituir os nulos pelo valor da média.
  #df['Notas'].fillna(df['Notas'].mean(), inplace=True)

#Caso as pessoas só perderam a prova,por exemplo, a alternativa que eu escolheria seria de substituir o valor por 0
df['Notas'].fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       0
# Aprovado    0
# dtype: int64

# %%
alunos_transferidos = df.query('Nome == "Alice" | Nome == "Carlos"').index

# %%
df.drop(alunos_transferidos, axis= 0, inplace=True)
df
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %%
Lista_de_Aprovados = df['Aprovado'] == True

# %%
df[Lista_de_Aprovados].head(10)
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %%
df[Lista_de_Aprovados].to_csv("alunos_aprovados.csv",index = False)

# %%
df['Notas'].replace(7,8,inplace = True)
df[Lista_de_Aprovados].to_csv("alunos_aprovados.csv",index = False)
df
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    8.0      True
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    8.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# 1) Os alunos participaram de uma atividade extracurricular e ganharam pontos extras. Esses pontos extras correspondem a 40% da nota atual de cada um deles. Com base nisso, crie uma coluna chamada "Pontos_extras" que contenha os pontos extras de cada aluno, ou seja, 40% da nota atual deles.
#
# 2) Crie mais uma coluna, chamada "Notas_finais" que possua as notas de cada aluno somada com os pontos extras.
#
# 3) Como houve uma pontuação extra, alguns alunos que não tinham sido aprovados antes podem ter sido aprovados agora. Com base nisso, crie uma coluna chamada "Aprovado_final" com os seguintes valores:
#
# True: caso o aluno esteja aprovado (nota final deve ser maior ou igual a 6);
# False: caso o aluno esteja reprovado (nota final deve ser menor que 6).
# 4) Faça uma seleção e verifique quais alunos não tinham sido aprovados anteriormente, mas foram aprovados após a soma dos pontos extras.

# %%
#1 Como queremos 40% do valor das notas, basta cria a coluna, e multiplicar as notas por 0.4, o que equivale a 40%
df['Pontos_extras'] = df['Notas'] * 0.4
df
# Out:
#          Nome  Idade  Notas  Aprovado  Pontas Extras  Pontaos_extras  \
# 0         Ary     20    7.5      True            3.0             3.0
# 1         Ana     18    0.0     False            0.0             0.0
# 2       Cátia     27    2.5     False            1.0             1.0
# 3       Denis     18    5.0     False            2.0             2.0
# 4        Beto     21   10.0      True            4.0             4.0
# 5       Bruna     23    0.0     False            0.0             0.0
# 6        Dara     21    8.0      True            3.2             3.2
# 9       Vitor     28    0.0     False            0.0             0.0
# 10     Daniel     21    0.0     False            0.0             0.0
# 11       Igor     24    4.5     False            1.8             1.8
# 12  Sthefanie     26    9.5      True            3.8             3.8
# 13      Mirla     25    9.0      True            3.6             3.6
# 14      Paulo     37    0.0     False            0.0             0.0
# 15     Mylena     29    8.0      True            3.2             3.2
# 16      Lucas     33    0.0     False            0.0             0.0
# 17      Nadia     34    8.0      True            3.2             3.2
#
#     Pontos_extras
# 0             3.0
# 1             0.0
# 2             1.0
# 3             2.0
# 4             4.0
# 5             0.0
# 6             3.2
# 9             0.0
# 10            0.0
# 11            1.8
# 12            3.8
# 13            3.6
# 14            0.0
# 15            3.2
# 16            0.0
# 17            3.2

# %%
#Soma das notas finais
df["Notas_finais"] = df['Notas'] + df['Pontos_extras']
df
# Out:
#          Nome  Idade  Notas  Aprovado  Pontas Extras  Pontaos_extras  \
# 0         Ary     20    7.5      True            3.0             3.0
# 1         Ana     18    0.0     False            0.0             0.0
# 2       Cátia     27    2.5     False            1.0             1.0
# 3       Denis     18    5.0     False            2.0             2.0
# 4        Beto     21   10.0      True            4.0             4.0
# 5       Bruna     23    0.0     False            0.0             0.0
# 6        Dara     21    8.0      True            3.2             3.2
# 9       Vitor     28    0.0     False            0.0             0.0
# 10     Daniel     21    0.0     False            0.0             0.0
# 11       Igor     24    4.5     False            1.8             1.8
# 12  Sthefanie     26    9.5      True            3.8             3.8
# 13      Mirla     25    9.0      True            3.6             3.6
# 14      Paulo     37    0.0     False            0.0             0.0
# 15     Mylena     29    8.0      True            3.2             3.2
# 16      Lucas     33    0.0     False            0.0             0.0
# 17      Nadia     34    8.0      True            3.2             3.2
#
#     Pontos_extras  Notas_finais
# 0             3.0          10.5
# 1             0.0           0.0
# 2             1.0           3.5
# 3             2.0           7.0
# 4             4.0          14.0
# 5             0.0           0.0
# 6             3.2          11.2
# 9             0.0           0.0
# 10            0.0           0.0
# 11            1.8           6.3
# 12            3.8          13.3
# 13            3.6          12.6
# 14            0.0           0.0
# 15            3.2          11.2
# 16            0.0           0.0
# 17            3.2          11.2

# %%
#Criando a lista de alunos aprovados após a adição de pontos
df["Aprovado_final"] = df['Notas_finais'].apply(lambda x: True if x >= 6 else False)
df
# Out:
#          Nome  Idade  Notas  Aprovado  Pontas Extras  Pontaos_extras  \
# 0         Ary     20    7.5      True            3.0             3.0
# 1         Ana     18    0.0     False            0.0             0.0
# 2       Cátia     27    2.5     False            1.0             1.0
# 3       Denis     18    5.0     False            2.0             2.0
# 4        Beto     21   10.0      True            4.0             4.0
# 5       Bruna     23    0.0     False            0.0             0.0
# 6        Dara     21    8.0      True            3.2             3.2
# 9       Vitor     28    0.0     False            0.0             0.0
# 10     Daniel     21    0.0     False            0.0             0.0
# 11       Igor     24    4.5     False            1.8             1.8
# 12  Sthefanie     26    9.5      True            3.8             3.8
# 13      Mirla     25    9.0      True            3.6             3.6
# 14      Paulo     37    0.0     False            0.0             0.0
# 15     Mylena     29    8.0      True            3.2             3.2
# 16      Lucas     33    0.0     False            0.0             0.0
# 17      Nadia     34    8.0      True            3.2             3.2
#
#     Pontos_extras  Notas_finais  Aprovado_final
# 0             3.0          10.5            True
# 1             0.0           0.0           False
# 2             1.0           3.5           False
# 3             2.0           7.0            True
# 4             4.0          14.0            True
# 5             0.0           0.0           False
# 6             3.2          11.2            True
# 9             0.0           0.0           False
# 10            0.0           0.0           False
# 11            1.8           6.3            True
# 12            3.8          13.3            True
# 13            3.6          12.6            True
# 14            0.0           0.0           False
# 15            3.2          11.2            True
# 16            0.0           0.0           False
# 17            3.2          11.2            True

# %%
#Lista de alunos aprovados após a adição de pontos que não foram aprovados anteriormente.
alunos_aprovados_depois = df[(df['Aprovado'] == False) & (df['Aprovado_final'] == True)]
alunos_aprovados_depois
# Out:
#      Nome  Idade  Notas  Aprovado  Pontas Extras  Pontaos_extras  \
# 3   Denis     18    5.0     False            2.0             2.0
# 11   Igor     24    4.5     False            1.8             1.8
#
#     Pontos_extras  Notas_finais  Aprovado_final
# 3             2.0           7.0            True
# 11            1.8           6.3            True
